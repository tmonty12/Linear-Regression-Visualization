# %%
import sys
sys.path.append('..')

# %%
from regression import regression

regression()
# Out:
# Enter number of coordinates : 5
# x: 0
# y: 1
# x: 3
# y: 2
# x: 4
# y: 7
# x: 8
# y: 8
# x: 10
# y: 9
